# %%
# Atividade 2 pseudocodigo


pseudocodigo_caixa = """
ALGORITMO SaqueCaixaEletronico
INÍCIO
    // Passo 1: Inicialização
    cartao_inserido ← FALSO
    autenticado ← FALSO
    valor_saque ← 0
    
    // Passo 2: Inserção do cartão
    ENQUANTO cartao_inserido = FALSO FAÇA
        EXIBIR "Por favor, insira seu cartão"
        cartao_inserido ← LER_SENSOR_CARTAO()
    FIM_ENQUANTO
    
    // Passo 3: Autenticação
    REPITA
        EXIBIR "Digite sua senha (4 dígitos):"
        senha_digitada ← LER_TECLADO(4)
        autenticado ← VERIFICAR_SENHA(senha_digitada)
        
        SE autenticado = FALSO ENTÃO
            EXIBIR "Senha incorreta. Tente novamente."
            tentativas ← tentativas + 1
            SE tentativas >= 3 ENTÃO
                EXIBIR "Cartão bloqueado. Contate seu banco."
                DEVOLVER_CARTAO()
                FIM
            FIM_SE
        FIM_SE
    ATÉ autenticado = VERDADEIRO
    
    // Passo 4: Menu principal
    OPCAO ← 0
    ENQUANTO OPCAO ≠ 4 FAÇA
        EXIBIR "Menu:"
        EXIBIR "1. Saldo"
        EXIBIR "2. Saque"
        EXIBIR "3. Extrato"
        EXIBIR "4. Sair"
        OPCAO ← LER_OPCAO()
        
        // Passo 5: Processar saque
        SE OPCAO = 2 ENTÃO
            EXIBIR "Digite o valor do saque:"
            valor_saque ← LER_VALOR()
            
            // Validações
            SE valor_saque % 10 ≠ 0 ENTÃO
                EXIBIR "Valor deve ser múltiplo de 10"
            SENÃO SE valor_saque > saldo_disponivel ENTÃO
                EXIBIR "Saldo insuficiente"
            SENÃO SE valor_saque > limite_diario ENTÃO
                EXIBIR "Limite diário excedido"
            SENÃO
                // Processar saque
                saldo_disponivel ← saldo_disponivel - valor_saque
                LIBERAR_DINHEIRO(valor_saque)
                EXIBIR "Retire seu dinheiro"
                
                // Comprovante
                EXIBIR "Deseja comprovante? (S/N)"
                resposta ← LER_RESPOSTA()
                SE resposta = 'S' ENTÃO
                    IMPRIMIR_COMPROVANTE(valor_saque, saldo_disponivel)
                FIM_SE
            FIM_SE
        FIM_SE
    FIM_ENQUANTO
    
    // Passo 6: Finalização
    EXIBIR "Retire seu cartão"
    DEVOLVER_CARTAO()
FIM
"""

# %%
#Atividade 3



pseudocodigo_media = """
ALGORITMO CalculaMedia
INÍCIO
    // Declaração de variáveis
    DECLARE nota1, nota2, media: REAL
    
    // Entrada de dados
    EXIBIR "Digite a primeira nota (0-10):"
    LEIA(nota1)
    
    EXIBIR "Digite a segunda nota (0-10):"
    LEIA(nota2)
    
    // Validação das notas
    SE (nota1 < 0) OU (nota1 > 10) OU (nota2 < 0) OU (nota2 > 10) ENTÃO
        EXIBIR "Erro: Notas devem estar entre 0 e 10"
    SENÃO
        // Cálculo da média
        media ← (nota1 + nota2) / 2
        
        // Exibição do resultado
        EXIBIR "A média das notas é: ", media
        
        // Classificação (opcional)
        SE media >= 7 ENTÃO
            EXIBIR "Situação: Aprovado"
        SENÃO SE media >= 4 ENTÃO
            EXIBIR "Situação: Recuperação"
        SENÃO
            EXIBIR "Situação: Reprovado"
        FIM_SE
    FIM_SE
FIM
"""
